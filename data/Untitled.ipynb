# %%
import geopandas as gpd

Schools
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5419d6804d60> in <module>
#       1 import geopandas as gpd
#       2
# ----> 3 Schools
#
# NameError: name 'Schools' is not defined

# %%
Schools_gdf = gdf.read_file('Schools.geojson')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4799d5bd78a8> in <module>
# ----> 1 Schools_gdf = gdf.read_file('Schools.geojson')
#
# NameError: name 'gdf' is not defined

# %%
import seaborn
import geopandas as gpd
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.colors import Normalize
from matplotlib import cm

# %%
Schools_gdf = gdf.read_file('Schools.geojson')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-4799d5bd78a8> in <module>
# ----> 1 Schools_gdf = gdf.read_file('Schools.geojson')
#
# NameError: name 'gdf' is not defined

# %%
Schools_gdf = gpd.read_file('Schools.geojson')
Schools_gdf.head(15)
# Out:
#     OBJECTID          AUN  SCHOOL_NUM LOCATION_ID  \
# 0          1  226517352.0         NaN        None
# 1          2  226519242.0         NaN        None
# 2          3  300518675.0         NaN        None
# 3          4  300513270.0         NaN        None
# 4          5  226514502.0         NaN        None
# 5          6  226511002.0         NaN        None
# 6          7  226515802.0         NaN        None
# 7          8  126513070.0      7557.0        3308
# 8          9          NaN         NaN        3322
# 9         10          NaN         NaN        3374
# 10        11  226510912.0         NaN        None
# 11        12  226519162.0         NaN        None
# 12        13  226519672.0         NaN        None
# 13        14  226518302.0         NaN        None
# 14        15  226515682.0         NaN        None
#
#                                      SCHOOL_NAME  \
# 0    St Frances Cabrini Regional Catholic School
# 1                St Pio Regional Catholic School
# ...

# %%
crash_data_collision_crash_2007_2017_gdf = gpd.read_file('crash_data_collision_crash_2007_2017.geojson')
crash_data_collision_crash_2007_2017_gdf.tail(15)
# Out:
#        objectid_1  objectid         crn  district  county  municipality  \
# 77447        2015     25989  2017035786         6      67         67301
# 77448        1730     22322  2017041416         6      67         67301
# 77449        1731     22375  2017033079         6      67         67301
# 77450        1732     22385  2017041404         6      67         67301
# 77451        1733     22411  2017017619         6      67         67301
# 77452        1734     22425  2017028843         6      67         67301
# 77453        1735     22435  2017043785         6      67         67301
# 77454        1736     22460  2017010586         6      67         67301
# 77455        1737     22475  2017033052         6      67         67301
# 77456        1738     22483  2017023942         6      67         67301
# 77457        1739     22491  2017060716         6      67         67301
# 77458        1740     22494  2017055573         6      67         67301
# ...

# %%
blood_lead_gdf = gpd.read_file('blood_lead.geojson')
blood_lead_gdf.head(15)
# Out:
#     id   census_tra  data_redac  num_bll_5p  num_screen  perc_5plus  \
# 0    0  42101000100           0         0.0       100.0         0.0
# 1    1  42101000200           1         NaN       109.0         NaN
# 2    2  42101000300           1         NaN       110.0         NaN
# 3    3  42101000401           1         NaN        61.0         NaN
# 4    4  42101000402           0         0.0        41.0         0.0
# 5    5  42101000500           1         NaN        49.0         NaN
# 6    6  42101000600           0         0.0        24.0         0.0
# 7    7  42101000700           0         0.0        57.0         0.0
# 8    8  42101000801           1         NaN        57.0         NaN
# 9    9  42101000803           0         0.0        63.0         0.0
# 10  10  42101000804           0         0.0        86.0         0.0
# 11  11  42101000901           0         0.0        21.0         0.0
# 12  12  42101000902           1         NaN        62.0         NaN
# ...

# %%
maxvalue = blood_lead_gdf['num_screen'].max()
minvalue = blood_lead_gdf['num_screen'].min()
stand = blood_lead_gdf['num_screen'].std()

print('The max, min, and standard deviation values are:', maxvalue, minvalue, stand)
# Out:
# The max, min, and standard deviation values are: 846.0 6.0 143.47553306685555
